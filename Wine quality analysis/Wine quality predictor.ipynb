# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# There are no Null values in the dataset

# %%
df.plot(kind = 'density',subplots = True, sharex =False, sharey = False, fontsize = 0.25,
        layout = (6,2),figsize=(8,12))
# Out:
# <img src="data:image/png;base64,..." width="799.6333333333333">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1faea8700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1faf1db80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fac7db20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fae09a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fada26d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fac458e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fac459d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fac7b1f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fabcd100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fab81820>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fabacfa0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fab60760>]],
#       dtype=object)

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %% [markdown]
# Observations:
#
# 1.Most of the features follow normal distribution, except wine quality
#
# 2.All the features will require Normalization + scaling
#
# 3.Wine quality can be either predicted as multi-class classification (4,5,...) or divide the wine in 2 or 3 classes: Good, Average, Bad

# %% [markdown]
# ### Correlation between variables

# %%
plt.figure().set_size_inches(10,8)
sns.heatmap(df.corr(), annot = True)
# Out:
# <img src="data:image/png;base64,..." width="999.7333333333333">

# %% [markdown]
# Many of the Features have moderate collinearity: around 0.67 and -0.68.
# Should we drop them??

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ## Fixed Acidity

# %%
plt.figure()
sns.barplot(y = df["fixed acidity"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
plt.figure()
sns.boxplot(y = df["fixed acidity"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# Though the range of the fixed acidity differs, median pretty much remains the same

# %% [markdown]
# ## volatile acidity

# %%
plt.figure()
sns.barplot(y = df["volatile acidity"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
plt.figure()
sns.boxplot(y = df["volatile acidity"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# Here we see a much clear pattern, Volatile acidity and wine quality are negatively correlated

# %% [markdown]
# ## 'citric acid'

# %%
plt.figure()
sns.barplot(y = df["citric acid"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
plt.figure()
sns.boxplot(y = df["citric acid"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# The median show a certain pattern, but the range of the bars are large and we cannot get a clear picture of wine quality with just the citric acid quantity

# %% [markdown]
# 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],

# %% [markdown]
# ## Residual Sugar

# %%
plt.figure()
sns.barplot(y = df["residual sugar"], x = df["quality"])
plt.figure()
sns.boxplot(y = df["residual sugar"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# The medians are uniform, no clear relation

# %% [markdown]
# ## Chlorides

# %%
plt.figure()
sns.barplot(y = df["chlorides"], x = df["quality"])
plt.figure()
sns.boxplot(y = df["chlorides"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# Amount of chloride decreases as quality increases, but there are multiple outliers in the dataset, so do we have to clean them?

# %%
'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality'
# Out:
# ('free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality')

# %% [markdown]
# ## Free sulfur dioxide

# %%
plt.figure()
sns.barplot(y = df["free sulfur dioxide"], x = df["quality"])
plt.figure()
sns.boxplot(y = df["free sulfur dioxide"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# ## total sulfur dioxide

# %%
plt.figure()
sns.barplot(y = df["total sulfur dioxide"], x = df["quality"])
plt.figure()
sns.boxplot(y = df["total sulfur dioxide"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# ## Density

# %%
plt.figure()
sns.barplot(y = df["density"], x = df["quality"])
plt.figure()
sns.boxplot(y = df["density"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# ## pH

# %%
plt.figure()
sns.barplot(y = df["pH"], x = df["quality"])
plt.figure()
sns.boxplot(y = df["pH"], x = df["quality"])
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# ## Alcohol

# %%
plt.figure()
sns.barplot(y = df["alcohol"], x = df["quality"])
plt.figure()
sns.boxplot(y = df["alcohol"], x = df["quality"])
# Out:
# <ipython-input-71-da3d33fab57f>:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <img src="data:image/png;base64,..." width="639.4">
# <ipython-input-71-da3d33fab57f>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# # Data preprocessing

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from scipy.stats import zscore
z = abs(zscore(df))
print(df.shape)
df = df.loc[(z<3).all(axis = 1)]
df.shape
# Out:
# (1599, 12)
# (1451, 12)

# %%
X = df.drop("quality", axis = 1)
y = df["quality"]

# %%
def log_tran(row):
    row = np.log(row + 1)
    return row
X_norm = X.apply(log_tran)
X_norm
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          2.128232          0.530628     0.000000        1.064711   0.073250
# 1          2.174752          0.631272     0.000000        1.280934   0.093490
# 2          2.174752          0.565314     0.039221        1.193922   0.088011
# 3          2.501436          0.246860     0.444686        1.064711   0.072321
# 4          2.128232          0.530628     0.000000        1.064711   0.073250
# ...             ...               ...          ...             ...        ...
# 1594       1.974081          0.470004     0.076961        1.098612   0.086178
# 1595       1.931521          0.438255     0.095310        1.163151   0.060154
# 1596       1.987874          0.412110     0.122218        1.193922   0.073250
# 1597       1.931521          0.497740     0.113329        1.098612   0.072321
# 1598       1.945910          0.270027     0.385262        1.526056   0.064851
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                2.484907              3.555348  0.692047  1.506297
# 1                3.258097              4.219508  0.691546  1.435085
# 2                2.772589              4.007333  0.691646  1.449269
# 3                2.890372              4.110874  0.692147  1.425515
# 4                2.484907              3.555348  0.692047  1.506297
# ...                   ...                   ...       ...       ...
# 1594             3.496508              3.806662  0.690594  1.492904
# 1595             3.688879              3.951244  0.690704  1.508512
# 1596             3.401197              3.713572  0.691015  1.486140
# 1597             3.496508              3.806662  0.690880  1.519513
# 1598             2.944439              3.761200  0.690890  1.479329
#
#       sulphates   alcohol
# 0      0.444686  2.341806
# 1      0.518794  2.379546
# 2      0.500775  2.379546
# 3      0.457425  2.379546
# 4      0.444686  2.341806
# ...         ...       ...
# 1594   0.457425  2.442347
# 1595   0.565314  2.501436
# 1596   0.559616  2.484907
# 1597   0.536493  2.415914
# 1598   0.506818  2.484907
#
# [1451 rows x 11 columns]

# %%
X_norm.plot(kind = 'density',subplots = True, sharex =False, sharey = False, fontsize = 0.25,
        layout = (6,2),figsize=(8,12))
# Out:
# /home/aditya/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:184: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)
# <img src="data:image/png;base64,..." width="799.6333333333333">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7d157f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7d2e910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7cd9d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7c92220>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7cbe670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1f80edfa0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1f80ede20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1fa53aca0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7d0d8b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7c5ec40>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7bbc130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1e7b74460>]],
#       dtype=object)

# %% [markdown]
# ## Train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_norm, y)

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Model 1: Decision Tree

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
dt_clf = DecisionTreeClassifier().fit(X_train_scaled, y_train)
y_predict = dt_clf.predict(X_test_scaled)
accuracy_score(y_test, y_predict)
# Out:
# 0.5482093663911846

# %% [markdown]
# ## Model 2: Knn

# %%
from sklearn.neighbors import KNeighborsClassifier
max_acc = 0
k = 0
for i in range(1,50,2):
    knn_clf = KNeighborsClassifier(n_neighbors = i).fit(X_train_scaled,y_train)
    y_predict = knn_clf.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_predict)
    if accuracy>max_acc:
        max_acc = accuracy
        k = i
    print("Accuracy score of k = {} is {}".format(i, accuracy))
print("Max accuracy score is {} for k = {}".format(max_acc, k))
# Out:
# Accuracy score of k = 1 is 0.6859504132231405
# Accuracy score of k = 3 is 0.6005509641873278
# Accuracy score of k = 5 is 0.6253443526170799
# Accuracy score of k = 7 is 0.6033057851239669
# Accuracy score of k = 9 is 0.6170798898071626
# Accuracy score of k = 11 is 0.6473829201101928
# Accuracy score of k = 13 is 0.628099173553719
# Accuracy score of k = 15 is 0.6143250688705234
# Accuracy score of k = 17 is 0.6088154269972452
# Accuracy score of k = 19 is 0.6143250688705234
# Accuracy score of k = 21 is 0.6170798898071626
# Accuracy score of k = 23 is 0.6170798898071626
# Accuracy score of k = 25 is 0.628099173553719
# Accuracy score of k = 27 is 0.6308539944903582
# Accuracy score of k = 29 is 0.6198347107438017
# Accuracy score of k = 31 is 0.6143250688705234
# Accuracy score of k = 33 is 0.6170798898071626
# Accuracy score of k = 35 is 0.6060606060606061
# Accuracy score of k = 37 is 0.6115702479338843
# Accuracy score of k = 39 is 0.6170798898071626
# Accuracy score of k = 41 is 0.6170798898071626
# Accuracy score of k = 43 is 0.6170798898071626
# Accuracy score of k = 45 is 0.6115702479338843
# Accuracy score of k = 47 is 0.6088154269972452
# Accuracy score of k = 49 is 0.6088154269972452
# Max accuracy score is 0.6859504132231405 for k = 1

# %% [markdown]
# ## Model 3: SVC

# %%
from sklearn.svm import SVC
svc_clf = SVC(kernel = 'linear').fit(X_train_scaled,y_train)
y_predict = svc_clf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.5922865013774105

# %% [markdown]
# ## Model 4: Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression(max_iter = 2000).fit(X_train_scaled,y_train)
y_predict = lr_clf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.6088154269972452

# %% [markdown]
# ## Model 5: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier().fit(X_train_scaled, y_train)
y_predict = rf_clf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.6749311294765841

# %% [markdown]
# # Tuning Parameters

# %%
from sklearn.model_selection import GridSearchCV 
lr = LogisticRegression()
param_grid = {'max_iter' : [2000],
              'penalty' : ['l1', 'l2'],
              'C' : np.logspace(-4, 4, 20),
              'solver' : ['liblinear', 'sag']}

lr_clf = GridSearchCV(lr, param_grid = param_grid, cv = 5, verbose = True, n_jobs = -1)
best_lr_clf = lr_clf.fit(X_train_scaled,y_train)
print('Best Score: ' + str(best_lr_clf.best_score_))
print('Best Parameters: ' + str(best_lr_clf.best_params_))
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:    0.2s
# Best Score: 0.6001902507081553
# Best Parameters: {'C': 1.623776739188721, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'sag'}
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed:    2.0s finished

# %%
svc = SVC(probability = False)
param_grid = tuned_parameters = [{'kernel': ['rbf'], 'gamma': [.1,.5,1,2,5,10],
                                  'C': [.1, 1, 10, 100, 1000]},
                                 {'kernel': ['linear'], 'C': [.1, 1, 10, 100, 1000]},
                                 ]
svc_clf = GridSearchCV(svc, param_grid = param_grid, cv = 3, verbose = True, n_jobs = -1)
best_svc_clf = svc_clf.fit(X_train_scaled,y_train)
print('Best Score: ' + str(best_svc_clf.best_score_))
print('Best Parameters: ' + str(best_svc_clf.best_params_))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# Fitting 3 folds for each of 35 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  94 out of 105 | elapsed:    0.8s remaining:    0.1s
# Best Score: 0.6360287962497908
# Best Parameters: {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    2.5s finished

# %% [markdown]
# We are not getting good results for our models.
# Maybe there are too many classes and not enough features, lets see if we can divide them and then train the models

# %%
def wine_qlty(row):
    if row<5:
        row = 1
    elif (row>4 and row<7):
        row = 2
    else:
        row = 3
    return row
y_train = y_train.apply(wine_qlty)
y_test = y_test.apply(wine_qlty)

# %% [markdown]
# Here, we have:
# 1 = Poor quality
# 2 = Average quality
# 3 = Good quality

# %% [markdown]
# ## Decision Tree

# %%
dt_clf = DecisionTreeClassifier().fit(X_train_scaled, y_train)
y_predict = dt_clf.predict(X_test_scaled)
accuracy_score(y_test, y_predict)
# Out:
# 0.7988980716253443

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
max_acc = 0
k = 0
for i in range(1,50,2):
    knn_clf = KNeighborsClassifier(n_neighbors = i).fit(X_train_scaled,y_train)
    y_predict = knn_clf.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_predict)
    if accuracy>max_acc:
        max_acc = accuracy
        k = i
    print("Accuracy score of k = {} is {}".format(i, accuracy))
print("Max accuracy score is {} for k = {}".format(max_acc, k))
# Out:
# Accuracy score of k = 1 is 0.837465564738292
# Accuracy score of k = 3 is 0.8319559228650137
# Accuracy score of k = 5 is 0.8760330578512396
# Accuracy score of k = 7 is 0.8705234159779615
# Accuracy score of k = 9 is 0.8705234159779615
# Accuracy score of k = 11 is 0.8842975206611571
# Accuracy score of k = 13 is 0.8787878787878788
# Accuracy score of k = 15 is 0.8650137741046832
# Accuracy score of k = 17 is 0.8650137741046832
# Accuracy score of k = 19 is 0.8677685950413223
# Accuracy score of k = 21 is 0.8760330578512396
# Accuracy score of k = 23 is 0.8787878787878788
# Accuracy score of k = 25 is 0.8705234159779615
# Accuracy score of k = 27 is 0.8760330578512396
# Accuracy score of k = 29 is 0.8622589531680441
# Accuracy score of k = 31 is 0.859504132231405
# Accuracy score of k = 33 is 0.8622589531680441
# Accuracy score of k = 35 is 0.8567493112947658
# Accuracy score of k = 37 is 0.8567493112947658
# Accuracy score of k = 39 is 0.8787878787878788
# Accuracy score of k = 41 is 0.8732782369146006
# Accuracy score of k = 43 is 0.8705234159779615
# Accuracy score of k = 45 is 0.8677685950413223
# Accuracy score of k = 47 is 0.8705234159779615
# Accuracy score of k = 49 is 0.8677685950413223
# Max accuracy score is 0.8842975206611571 for k = 11

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC
svc_clf = SVC(kernel = 'linear').fit(X_train_scaled,y_train)
y_predict = svc_clf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.8402203856749312

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier().fit(X_train_scaled, y_train)
y_predict = rf_clf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.8732782369146006

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression(max_iter = 2000).fit(X_train_scaled,y_train)
y_predict = lr_clf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.859504132231405

# %% [markdown]
# # Tuning Parameters

# %%
from sklearn.model_selection import GridSearchCV 
lr = LogisticRegression()
param_grid = {'max_iter' : [2000],
              'penalty' : ['l1', 'l2'],
              'C' : np.logspace(-4, 4, 20),
              'solver' : ['liblinear', 'sag']}

lr_clf = GridSearchCV(lr, param_grid = param_grid, cv = 5, verbose = True, n_jobs = -1)
best_lr_clf = lr_clf.fit(X_train_scaled,y_train)
print('Best Score: ' + str(best_lr_clf.best_score_))
print('Best Parameters: ' + str(best_lr_clf.best_params_))
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:    0.1s
# Best Score: 0.8547964317422737
# Best Parameters: {'C': 78.47599703514607, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'sag'}
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed:    1.2s finished

# %%
y_predict = best_lr_clf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.8539944903581267

# %%
svc = SVC(probability = False)
param_grid = tuned_parameters = [{'kernel': ['rbf'], 'gamma': [.1,.5,1,2,5,10],
                                  'C': [.1, 1, 10, 100, 1000]},
                                 {'kernel': ['linear'], 'C': [.1, 1, 10, 100, 1000]},
                                 ]
svc_clf = GridSearchCV(svc, param_grid = param_grid, cv = 3, verbose = True, n_jobs = -1)
best_svc_clf = svc_clf.fit(X_train,y_train)
print('Best Score: ' + str(best_svc_clf.best_score_))
print('Best Parameters: ' + str(best_svc_clf.best_params_))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# Fitting 3 folds for each of 35 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  94 out of 105 | elapsed:    0.5s remaining:    0.1s
# Best Score: 0.852028573023048
# Best Parameters: {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    1.8s finished

# %%
y_predict = best_svc_clf.predict(X_test)
accuracy_score(y_test, y_predict)
# Out:
# 0.8650137741046832

# %% [markdown]
# Thus we get much better score by having only 3 classes to predict wine quality.
#
# Here we can choose SVC classifier ('C': 1000, 'gamma': 0.1, 'kernel': 'rbf') or KNN classifier with k=11 or Random forest
